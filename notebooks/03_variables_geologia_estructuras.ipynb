# %% [markdown]
# # 03 · Geología y estructuras — fase D
#
# Consume la fase C indicada en `config/features.yaml`. Ejecutar con el entorno `.venv-fase-a` y `requirements-fase-d.txt` instalado.
#
# **Ejecutar la siguiente celda inicia una nueva ejecución D.** Los cuadernos 04–06 recuperan esa ejecución mediante `reports/fase_d/current_run.json`; se muestra su ruta para evitar mezclar productos. Para continuar una ejecución ya iniciada, sustituir `start_run(ROOT)` por `current_run(ROOT)`.
#
# Las fracciones representan unidades cartográficas originales (incluidas mezclas), no porcentajes inventados de cada roca. GEODE es la única fuente estructural de V1. Las densidades son aproximaciones circulares a partir de longitudes por celda; no acreditan cobertura de levantamiento.

# %%
from pathlib import Path
import sys
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'src/geoau/features.py').exists())
if str(ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(ROOT / 'src'))
import pandas as pd
import matplotlib.pyplot as plt
from geoau import features as fd

RUN = fd.start_run(ROOT)
print(RUN)
# Out:
# Ejecución D: C:\Users\Lenovo\Desktop\PROYECTO IA\Proyecto Con Luis\reports\fase_d\20260908T131414_539995Z
# C:\Users\Lenovo\Desktop\PROYECTO IA\Proyecto Con Luis\reports\fase_d\20260908T131414_539995Z

# %% [markdown]
# ## Unidades y edades
# Intersecciones exactas con la parte terrestre de cada celda. Se disuelve por categoría; los solapes entre categorías y atributos ausentes se auditan. Revisar `dictionaries/litologia.csv` y `edades.csv`.

# %%
geology, geology_quality = fd.geology(ROOT, RUN)
display(geology.head())
display(geology_quality.describe())
# Out:
# litologia teselas 10
# litologia teselas 20
# litologia teselas 30
# litologia teselas 40
# litologia teselas 50
# litologia teselas 60
# litologia teselas 70
# edades teselas 10
# edades teselas 20
# edades teselas 30
# edades teselas 40
# edades teselas 50
# edades teselas 60
# edades teselas 70
#                            cell_id litologia_dominante  \
# 0  es_pen_utm30_1km_v1_r0000_c0172                 NaN
# 1  es_pen_utm30_1km_v1_r0000_c0173                 NaN
# 2  es_pen_utm30_1km_v1_r0001_c0172                 NaN
# 3  es_pen_utm30_1km_v1_r0001_c0173                 NaN
# 4  es_pen_utm30_1km_v1_r0001_c0174                 NaN
#
#    litologia_u000_fraccion  litologia_u001_fraccion  litologia_u002_fraccion  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    litologia_u003_fraccion  litologia_u004_fraccion  litologia_u005_fraccion  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    litologia_u006_fraccion  litologia_u007_fraccion  ...  \
# 0                      NaN                      NaN  ...
# 1                      NaN                      NaN  ...
# 2                      NaN                      NaN  ...
# 3                      NaN                      NaN  ...
# 4                      NaN                      NaN  ...
#
#    edades_u018_fraccion  edades_u019_fraccion  edades_u020_fraccion  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    edades_u021_fraccion  edades_u022_fraccion  edades_u023_fraccion  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    edades_u025_fraccion  edades_u026_fraccion  edades_u027_fraccion  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    edades_u028_fraccion
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 50 columns]
#        litologia_cobertura  litologia_solape_fraccion  \
# count        496855.000000               4.968550e+05
# mean              0.995171               1.620077e-16
# std               0.059709               2.249489e-14
# min               0.000000               0.000000e+00
# 25%               1.000000               0.000000e+00
# 50%               1.000000               0.000000e+00
# 75%               1.000000               0.000000e+00
# max               1.000000               9.740919e-12
#
#        litologia_sin_atributo_fraccion  edades_cobertura  \
# count                    496855.000000     496855.000000
# mean                          0.011094          0.995171
# std                           0.085611          0.059709
# min                           0.000000          0.000000
# 25%                           0.000000          1.000000
# 50%                           0.000000          1.000000
# 75%                           0.000000          1.000000
# max                           1.000000          1.000000
#
#        edades_solape_fraccion  edades_sin_atributo_fraccion
# count            4.968550e+05                 496855.000000
# mean             1.632932e-16                      0.011094
# std              2.248530e-14                      0.085611
# min              0.000000e+00                      0.000000
# 25%              0.000000e+00                      0.000000
# 50%              0.000000e+00                      0.000000
# 75%              0.000000e+00                      0.000000
# max              9.740919e-12                      1.000000

# %% [markdown]
# ## Estructuras
# Las reglas textuales excluyen agua/bordes y separan supuestas. Distancias a trazas hasta 10 km; sin coincidencia se conserva NaN y una bandera auxiliar. Revisar `dictionaries/estructuras.csv`. Las trazas cartografiadas no equivalen a una red completa.

# %%
structural, structural_quality = fd.lines(ROOT, RUN)
display(structural.describe())
# Out:
# structural teselas 5
# structural teselas 10
# structural teselas 15
# structural teselas 20
# structural teselas 25
# structural teselas 30
# structural teselas 35
# structural teselas 40
# structural teselas 45
# structural teselas 50
# structural teselas 55
# structural teselas 60
# structural teselas 65
# structural teselas 70
#        dist_falla_cartografiada_m  \
# count               402953.000000
# mean                  1967.229736
# std                   2254.545898
# min                      0.000045
# 25%                    373.814911
# 50%                   1056.247070
# 75%                   2701.466309
# max                   9999.874023
#
#        dens_aprox_falla_cartografiada_1000m_km_km2  \
# count                                 4.968550e+05
# mean                                  3.222059e-01
# std                                   5.648701e-01
# min                                   0.000000e+00
# 25%                                   4.391950e-17
# 50%                                   8.137991e-03
# 75%                                   4.432352e-01
# max                                   8.816089e+00
#
#        dens_aprox_falla_cartografiada_5000m_km_km2  \
# count                                 4.968550e+05
# mean                                  3.225735e-01
# std                                   4.105870e-01
# min                                   0.000000e+00
# 25%                                   2.698414e-16
# 50%                                   1.668921e-01
# 75%                                   5.014109e-01
# max                                   3.936674e+00
#
#        dens_aprox_falla_cartografiada_10000m_km_km2  dist_falla_supuesta_m  \
# count                                 496855.000000          346767.000000
# mean                                       0.322462            3653.515625
# std                                        0.350966            2631.576416
# min                                        0.000000               0.039505
# 25%                                        0.019144            1451.082520
# 50%                                        0.224339            3078.552734
# 75%                                        0.502601            5486.524414
# max                                        2.763320            9999.976562
#
#        dens_aprox_falla_supuesta_1000m_km_km2  \
# count                            4.968550e+05
# mean                             4.162293e-02
# std                              1.443276e-01
# min                              0.000000e+00
# 25%                              0.000000e+00
# 50%                              1.756780e-17
# 75%                              8.208356e-17
# max                              3.495949e+00
#
#        dens_aprox_falla_supuesta_5000m_km_km2  \
# count                            4.968550e+05
# mean                             4.174748e-02
# std                              8.965085e-02
# min                              0.000000e+00
# 25%                              8.221500e-18
# 50%                              1.584681e-03
# 75%                              4.499523e-02
# max                              1.420436e+00
#
#        dens_aprox_falla_supuesta_10000m_km_km2  \
# count                             4.968550e+05
# mean                              4.178464e-02
# std                               7.088065e-02
# min                               0.000000e+00
# 25%                               2.020297e-17
# 50%                               1.335523e-02
# 75%                               5.218658e-02
# max                               8.389087e-01
#
#        dist_cabalgamiento_cartografiada_m  \
# count                       220181.000000
# mean                          3949.449463
# std                           2904.181641
# min                              0.002795
# 25%                           1341.593994
# 50%                           3438.185303
# 75%                           6282.181641
# max                           9999.800781
#
#        dens_aprox_cabalgamiento_cartografiada_1000m_km_km2  ...  \
# count                                       4.968550e+05    ...
# mean                                        5.754295e-02    ...
# std                                         2.327057e-01    ...
# min                                         0.000000e+00    ...
# 25%                                         0.000000e+00    ...
# 50%                                         1.756780e-17    ...
# 75%                                         7.905510e-17    ...
# max                                         5.458712e+00    ...
#
#        dens_aprox_cabalgamiento_supuesta_5000m_km_km2  \
# count                                    4.968550e+05
# mean                                     7.668195e-03
# std                                      3.617522e-02
# min                                      0.000000e+00
# 25%                                      0.000000e+00
# 50%                                      2.256539e-18
# 75%                                      9.575362e-18
# max                                      7.309799e-01
#
#        dens_aprox_cabalgamiento_supuesta_10000m_km_km2  \
# count                                     4.968550e+05
# mean                                      7.689622e-03
# std                                       2.952266e-02
# min                                       0.000000e+00
# 25%                                       0.000000e+00
# 50%                                       2.622194e-18
# 75%                                       1.278644e-17
# max                                       3.827811e-01
#
#        dist_contacto_intrusivo_cartografiada_m  \
# count                            149232.000000
# mean                               3057.513916
# std                                2870.612549
# min                                   0.004934
# 25%                                 609.983826
# 50%                                2028.964233
# 75%                                5053.385254
# max                                9999.937500
#
#        dens_aprox_contacto_intrusivo_cartografiada_1000m_km_km2  \
# count                                       4.968550e+05
# mean                                        1.249361e-01
# std                                         5.839527e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         4.391950e-17
# 75%                                         1.892710e-16
# max                                         1.893927e+01
#
#        dens_aprox_contacto_intrusivo_cartografiada_5000m_km_km2  \
# count                                       4.968550e+05
# mean                                        1.249328e-01
# std                                         4.576436e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         5.665615e-17
# 75%                                         2.833903e-16
# max                                         1.035905e+01
#
#        dens_aprox_contacto_intrusivo_cartografiada_10000m_km_km2  \
# count                                       4.968550e+05
# mean                                        1.248059e-01
# std                                         3.942286e-01
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         5.217817e-17
# 75%                                         1.941076e-02
# max                                         6.646314e+00
#
#        dist_contacto_intrusivo_supuesta_m  \
# count                         9942.000000
# mean                          5603.583008
# std                           2779.984619
# min                              0.253510
# 25%                           3352.558594
# 50%                           5838.069336
# 75%                           8009.525391
# max                           9998.984375
#
#        dens_aprox_contacto_intrusivo_supuesta_1000m_km_km2  \
# count                                       4.968550e+05
# mean                                        5.982803e-04
# std                                         2.110119e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         2.686386e-18
# max                                         3.238483e+00
#
#        dens_aprox_contacto_intrusivo_supuesta_5000m_km_km2  \
# count                                       4.968550e+05
# mean                                        6.003325e-04
# std                                         1.111512e-02
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         3.488346e-20
# 75%                                         1.389932e-18
# max                                         6.592413e-01
#
#        dens_aprox_contacto_intrusivo_supuesta_10000m_km_km2
# count                                       4.968550e+05
# mean                                        6.031113e-04
# std                                         7.551312e-03
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         9.121712e-19
# max                                         2.605421e-01
#
# [8 rows x 24 columns]

# %%
display(pd.read_csv(RUN / 'dictionaries/estructuras.csv'))
print('Continuar con 04 usando esta ejecución:', RUN)
# Out:
#                                           description  entities  \
# 0                                Contacto discordante    793282
# 1                                               Falla    457994
# 2                       Contacto normal o concordante    273072
# 3                                       Masas de agua    140271
# 4                                  Contacto intrusivo     66853
# 5                                       Cabalgamiento     46134
# 6                                       Traza de capa     42951
# 7                             Falla supuesta (oculta)     42784
# 8                                   Contacto mecánico     41702
# 9          Falla normal con indicación de hundimiento     28995
# 10                                  Contacto supuesto     12694
# 11                                  Límite de terraza     10893
# 12                                      Falla inversa      9766
# 13                             Cabalgamiento supuesto      5916
# 14                           Cambio lateral de facies      4536
# 15                         Falla de desgarre sinistra      3721
# 16                           Falla de desgarre dextra      3651
# 17                      Contacto discordante supuesto      3576
# 18                          Cicatriz de deslizamiento      2914
# 19                               Despegue extensional      2558
# 20                   Límite político - administrativo      2453
# 21  Falla normal supuesta con indicación de hundim...      2441
# 22                                    Zona de cizalla      1958
# 23                                             Dolina      1766
# 24                            Frente de deslizamiento      1354
# 25                             Falla inversa supuesta      1108
# 26                                         Escombrera      1080
# 27                 Límite de metamorfismo de contacto       886
# 28               Auréola de metamorfismo  de contacto       778
# 29                Contacto oculto o no cartografiable       710
# 30                             Simbología Cuaternario       534
# 31                       Contacto intrusivo  supuesto       354
# 32                  Falla de desgarre dextra supuesta       331
# 33                Falla de desgarre sinistra supuesta       273
# 34                             Zona de cizalla dúctil       273
# 35                        Contacto entre cuaternarios       220
# 36                      Despegue extensional supuesto       147
# 37                                          Antrópico       131
# 38                                       Rasa litoral        74
# 39                   Límite de construcción portuaria        72
# 40                                     Capa de carbón        30
# 41                   Frente de deslizamiento supuesto        17
# 42                 Cicatriz de deslizamiento supuesta        17
# 43                                      Borde de hoja        12
# 44                                        Dique ácido         3
#
#                                group                                    status
# 0                           excluido  regla textual candidata; revisar leyenda
# 1                falla_cartografiada  regla textual candidata; revisar leyenda
# 2                           excluido  regla textual candidata; revisar leyenda
# 3                           excluido  regla textual candidata; revisar leyenda
# 4   contacto_intrusivo_cartografiada  regla textual candidata; revisar leyenda
# 5        cabalgamiento_cartografiada  regla textual candidata; revisar leyenda
# 6                           excluido  regla textual candidata; revisar leyenda
# 7                     falla_supuesta  regla textual candidata; revisar leyenda
# 8                           excluido  regla textual candidata; revisar leyenda
# 9                falla_cartografiada  regla textual candidata; revisar leyenda
# 10                          excluido  regla textual candidata; revisar leyenda
# 11                          excluido  regla textual candidata; revisar leyenda
# 12               falla_cartografiada  regla textual candidata; revisar leyenda
# 13            cabalgamiento_supuesta  regla textual candidata; revisar leyenda
# 14                          excluido  regla textual candidata; revisar leyenda
# 15               falla_cartografiada  regla textual candidata; revisar leyenda
# 16               falla_cartografiada  regla textual candidata; revisar leyenda
# 17                          excluido  regla textual candidata; revisar leyenda
# 18                          excluido  regla textual candidata; revisar leyenda
# 19                          excluido  regla textual candidata; revisar leyenda
# 20                          excluido  regla textual candidata; revisar leyenda
# 21                    falla_supuesta  regla textual candidata; revisar leyenda
# 22               falla_cartografiada  regla textual candidata; revisar leyenda
# 23                          excluido  regla textual candidata; revisar leyenda
# 24                          excluido  regla textual candidata; revisar leyenda
# 25                    falla_supuesta  regla textual candidata; revisar leyenda
# 26                          excluido  regla textual candidata; revisar leyenda
# 27                          excluido  regla textual candidata; revisar leyenda
# 28                          excluido  regla textual candidata; revisar leyenda
# 29                          excluido  regla textual candidata; revisar leyenda
# 30                          excluido  regla textual candidata; revisar leyenda
# 31       contacto_intrusivo_supuesta  regla textual candidata; revisar leyenda
# 32                    falla_supuesta  regla textual candidata; revisar leyenda
# 33                    falla_supuesta  regla textual candidata; revisar leyenda
# 34               falla_cartografiada  regla textual candidata; revisar leyenda
# 35                          excluido  regla textual candidata; revisar leyenda
# 36                          excluido  regla textual candidata; revisar leyenda
# 37                          excluido  regla textual candidata; revisar leyenda
# 38                          excluido  regla textual candidata; revisar leyenda
# 39                          excluido  regla textual candidata; revisar leyenda
# 40                          excluido  regla textual candidata; revisar leyenda
# 41                          excluido  regla textual candidata; revisar leyenda
# 42                          excluido  regla textual candidata; revisar leyenda
# 43                          excluido  regla textual candidata; revisar leyenda
# 44                          excluido  regla textual candidata; revisar leyenda
# Continuar con 04 usando esta ejecución: C:\Users\Lenovo\Desktop\PROYECTO IA\Proyecto Con Luis\reports\fase_d\20260908T131414_539995Z
